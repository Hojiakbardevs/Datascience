# %% [markdown]
# <a href="https://colab.research.google.com/github/Hojiakbardevs/Datascience/blob/main/world_cities_air_quality_and_water_polution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math

# %%
# !unzip archive.zip
# Out:
# unzip:  cannot find or open archive.zip, archive.zip.zip or archive.zip.ZIP.

# %% [markdown]
# Dunyo shaharlarning havo va suv sifati malumotlar ustida ammalar

# %%
df = pd.read_csv('world_data.csv')
df.head(10)
# Out:
#                City                 "Region"                    "Country"  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
# 5              Bern         "Canton of Bern"                "Switzerland"
# 6            Geneva       "Canton of Geneva"                "Switzerland"
# 7            Zurich       "Canton of Zurich"                "Switzerland"
# 8             Basel                       ""                "Switzerland"
# 9            London                "England"             "United Kingdom"
#
#     "AirQuality"   "WaterPollution"
# 0      46.816038          49.504950
# 1      66.129032          49.107143
# 2      60.514019          43.000000
# ...

# %% [markdown]
# men columndagi dataframelarni o'zgartirdim

# %%
columns = ['City','Region','Country','Airquality','Waterpollution']
df.columns = columns
df
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#       Airquality  Waterpollution
# ...

# %% [markdown]
# keling qo'shtirnoqlarni olib tashlayman

# %%
df['Region'] = df['Region'].map(lambda x: x.replace('"',''))
df
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#       Airquality  Waterpollution
# 0      46.816038       49.504950
# ...

# %%
df['Country'] = df['Country'].map(lambda x: x.replace('"',''))
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       Airquality  Waterpollution
# 0      46.816038       49.504950
# ...

# %%
# !pip install xlwt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import xlwt

# %%
df.to_excel('Updated_data.xls')
# Out:
# <ipython-input-10-a8d79df7c377>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('Updated_data.xls')

# %%
df['Country'] = df['Country'].map(lambda x: x.strip())
df[df['Country'] == 'Germany']
# Out:
#                         City                   Region  Country  Airquality  \
# 3                     Berlin                           Germany   62.364130
# 28                   Cologne   North Rhine-Westphalia  Germany   60.714286
# 40                      Bonn   North Rhine-Westphalia  Germany   82.812500
# 52                 Heilbronn        Baden-Wurttemberg  Germany   80.000000
# 76                    Aachen   North Rhine-Westphalia  Germany   70.454545
# ...                      ...                      ...      ...         ...
# 2693             Bad Waldsee        Baden-Wurttemberg  Germany  100.000000
# 2714  Weilheim in Oberbayern                  Bavaria  Germany  100.000000
# 2727                  Buckow              Brandenburg  Germany   87.500000
# 3942                  Erfurt                Thuringia  Germany   85.000000
# 3943  Garmisch-Partenkirchen                  Bavaria  Germany  100.000000
#
#       Waterpollution
# 3          28.612717
# 28         27.777778
# ...

# %% [markdown]
# endi men O'zbekistondan havoni malumotlarni kiritishni hoxlayman

# %%
df[df['Country'] == 'Uzbekistan']
# Out:
#         City Region     Country  Airquality  Waterpollution
# 21  Tashkent         Uzbekistan   56.451613       49.166667

# %%
df['Region'] = df['Region'].map(lambda x: x.strip())
df[df['Region'] == 'Bavaria']
# Out:
#                         City   Region  Country  Airquality  Waterpollution
# 144                   Munich  Bavaria  Germany   74.418605       15.466102
# 197                Nuremberg  Bavaria  Germany   75.000000       12.500000
# 233                 Augsburg  Bavaria  Germany   73.529412       26.923077
# 264               Regensburg  Bavaria  Germany   87.500000        7.142857
# 266               Ingolstadt  Bavaria  Germany  100.000000        0.000000
# 280                 Erlangen  Bavaria  Germany   81.250000       29.166667
# 376                 Bayreuth  Bavaria  Germany   75.000000        0.000000
# 381                  Bamberg  Bavaria  Germany   95.833333       12.500000
# 383            Aschaffenburg  Bavaria  Germany   77.777778       40.000000
# 394                  Neu-Ulm  Bavaria  Germany  100.000000       50.000000
# 395              Schweinfurt  Bavaria  Germany   87.500000       62.500000
# ...

# %%
df
# Out:
#                   City                Region                   Country  \
# 0        New York City              New York  United States of America
# 1     Washington, D.C.  District of Columbia  United States of America
# 2        San Francisco            California  United States of America
# 3               Berlin                                         Germany
# 4          Los Angeles            California  United States of America
# ...                ...                   ...                       ...
# 3958             Yanbu       Medina Province              Saudi Arabia
# 3959           Cordoba             Andalusia                     Spain
# 3960               Vic             Catalonia                     Spain
# 3961           Segovia      Castile and Leon                     Spain
# 3962       Zamora city      Castile and Leon                     Spain
#
#       Airquality  Waterpollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %% [markdown]
# Men faqat new york uchun dataframeni oldim

# %%
df[df['Region']=='New York']
# Out:
#                City    Region                   Country  Airquality  \
# 0     New York City  New York  United States of America   46.816038
# 710        Brooklyn  New York  United States of America   52.083333
# 747          Albany  New York  United States of America   87.500000
# 926         Buffalo  New York  United States of America   77.083333
# 1095      Rochester  New York  United States of America   64.705882
# 1478        Yonkers  New York  United States of America  100.000000
# 1479  Niagara Falls  New York  United States of America  100.000000
# 1491     Oyster Bay  New York  United States of America  100.000000
# 1775   Poughkeepsie  New York  United States of America   91.666667
# 2164     Binghamton  New York  United States of America   62.500000
# 2319     Middletown  New York  United States of America  100.000000
# 2364    Schenectady  New York  United States of America   50.000000
# 2519   White Plains  New York  United States of America   37.500000
# ...

# %% [markdown]
# pivot table yordamida malumotlarni chiroyli tartiblashyman

# %%
df1 = pd.pivot_table(df, index = ['Country','City'])
# Out:
# <ipython-input-16-80747e2c91fe>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df1 = pd.pivot_table(df, index = ['Country','City'])

# %% [markdown]
# endi men O'zbekiston va  Germaniya shaharlarni ko'rsataman

# %%
df1.loc[['Uzbekistan', 'Germany']]
# Out:
#                           Airquality  Waterpollution
# Country    City
# Uzbekistan Tashkent        56.451613       49.166667
# Germany    Aachen          70.454545       17.857143
#            Aalen           87.500000       50.000000
#            Abensberg      100.000000       50.000000
#            Amberg         100.000000       50.000000
# ...                              ...             ...
#            Wilhelmshaven  100.000000       50.000000
#            Wolfsburg       96.875000        0.000000
#            Worms           60.000000      100.000000
#            Wuppertal       90.000000        0.000000
#            Zwickau         75.000000       50.000000
#
# [125 rows x 2 columns]

# %%
df1
# Out:
#                       Airquality  Waterpollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
def get_cost(sqft_walls, sqft_ceiling, sqft_per_gallon, cost_per_gallon):
    total_sqft = sqft_walls + sqft_ceiling
    gallons_needed = total_sqft / sqft_per_gallon
    cost = cost_per_gallon * gallons_needed
    return cost

number = get_cost(432,144,400,15)
math.ceil(number)
# Out:
# 22

# %%
df2 = df1.copy()
df2
# Out:
#                       Airquality  Waterpollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df2['WaterQuality'] = 100 - df2['Waterpollution']
df2
# Out:
#                       Airquality  Waterpollution  AirPolution  WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000    50.000000     50.000000
#             Farah     100.000000        0.000000     0.000000    100.000000
#             Herat      43.750000       31.250000    56.250000     68.750000
#             Kabul      18.421053       81.060606    81.578947     18.939394
#             Kandahar    0.000000       75.000000   100.000000     25.000000
# ...                          ...             ...          ...           ...
# Zambia      Mansa      75.000000       25.000000    25.000000     75.000000
# Zimbabwe    Bindura    50.000000       75.000000    50.000000     25.000000
#             Bulawayo   67.857143       71.428571    32.142857     28.571429
#             Harare     38.461538       87.500000    61.538462     12.500000
#             Masvingo   25.000000       62.500000    75.000000     37.500000
#
# [3895 rows x 4 columns]

# %%
df3 = pd.DataFrame(df2.values, index=df2.index, columns=[['Air','Air', 'Water', 'Water'],['Airquality', 'AirPolution',	'WaterQuality', 'Waterpollution']])
df3
# Out:
#                              Air                    Water
#                       Airquality AirPolution WaterQuality Waterpollution
# Country     City
# Afghanistan Andkhoy    50.000000   50.000000    50.000000      50.000000
#             Farah     100.000000    0.000000     0.000000     100.000000
#             Herat      43.750000   31.250000    56.250000      68.750000
#             Kabul      18.421053   81.060606    81.578947      18.939394
#             Kandahar    0.000000   75.000000   100.000000      25.000000
# ...                          ...         ...          ...            ...
# Zambia      Mansa      75.000000   25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000   75.000000    50.000000      25.000000
#             Bulawayo   67.857143   71.428571    32.142857      28.571429
#             Harare     38.461538   87.500000    61.538462      12.500000
#             Masvingo   25.000000   62.500000    75.000000      37.500000
#
# ...

# %%
df3['Air']
# Out:
#                       Airquality  AirPolution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000
#             Farah     100.000000     0.000000
#             Herat      43.750000    31.250000
#             Kabul      18.421053    81.060606
#             Kandahar    0.000000    75.000000
# ...                          ...          ...
# Zambia      Mansa      75.000000    25.000000
# Zimbabwe    Bindura    50.000000    75.000000
#             Bulawayo   67.857143    71.428571
#             Harare     38.461538    87.500000
#             Masvingo   25.000000    62.500000
#
# [3895 rows x 2 columns]

# %%
df3.columns.names = ['Object','Info']
df3
# Out:
# Object                       Air                    Water
# Info                  Airquality AirPolution WaterQuality Waterpollution
# Country     City
# Afghanistan Andkhoy    50.000000   50.000000    50.000000      50.000000
#             Farah     100.000000    0.000000     0.000000     100.000000
#             Herat      43.750000   31.250000    56.250000      68.750000
#             Kabul      18.421053   81.060606    81.578947      18.939394
#             Kandahar    0.000000   75.000000   100.000000      25.000000
# ...                          ...         ...          ...            ...
# Zambia      Mansa      75.000000   25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000   75.000000    50.000000      25.000000
#             Bulawayo   67.857143   71.428571    32.142857      28.571429
#             Harare     38.461538   87.500000    61.538462      12.500000
#             Masvingo   25.000000   62.500000    75.000000      37.500000
#
# ...

# %%
df3.index.names
# Out:
# FrozenList(['Country', 'City'])
