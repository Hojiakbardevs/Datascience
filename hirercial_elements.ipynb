# %% [markdown]
# <a href="https://colab.research.google.com/github/Hojiakbardevs/Datascience/blob/main/hirercial_elements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.Series(np.random.randn(9), index = ['a','a','a','b','b','c','c','d','d'])
pd.DataFrame(data)
# Out:
#           0
# a  0.171230
# a -1.065016
# a -0.515516
# b  2.275956
# b -0.493862
# c -0.778769
# c  1.545701
# d  0.734685
# d  1.281351

# %%
data1 = pd.Series(np.random.randn(9),
                  index = [['a','a','a','b','b','c','c','d','d'],[1,2,3,1,3,1,2,2,3]])
data1.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )
